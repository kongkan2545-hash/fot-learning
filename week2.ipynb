# %%
import numpy as np
import json
import os
import pandas as pd

# %%
#csv
#write
import csv
with open("data.csv", "w", newline="") as f:    #ให้code ไปopen ไฟล์ชื่อว่า data.csv
    writer = csv.writer(f)                      #ให้ตัวแปรรับผลลัพธ์csvที่ใช้คำสั่งwriter
    writer.writerow(["name", "age"])            #เพิ่มข้อมูล
    writer.writerow(["Alice", 20])              #เพิ่มข้อมูล

#read    
with open("data.csv", "r") as f:                #
reader = csv.reader(f)                          #
for row in reader:                              #
print(row)                                      #
